# %%
import search
search.soundcloud_url_call('come aliv3', limit=5)
# Out:
# {'collection': [{'artwork_url': 'https://i1.sndcdn.com/artworks-zWlsHiagmCdrOApn-wTgrzQ-large.png',
#    'caption': None,
#    'commentable': True,
#    'comment_count': 183,
#    'created_at': '2024-11-26T22:52:20Z',
#    'description': '',
#    'downloadable': False,
#    'download_count': 0,
#    'duration': 207464,
#    'full_duration': 207464,
#    'embeddable_by': 'all',
#    'genre': 'nolimit',
#    'has_downloads_left': False,
#    'id': 1967825335,
#    'kind': 'track',
#    'label_name': '',
#    'last_modified': '2024-12-06T20:11:26Z',
#    'license': 'all-rights-reserved',
#    'likes_count': 6663,
#    'permalink': 'come-aliv3',
#    'permalink_url': 'https://soundcloud.com/knock2music/come-aliv3',
#    'playback_count': 153620,
#    'public': True,
#    'publisher_metadata': {'id': 1967825335,
#     'urn': 'soundcloud:tracks:1967825335',
#     'artist': 'Knock2',
#     'contains_music': True,
#     'isrc': 'QMDA72473467',
#     'explicit': False},
# ...

# %%
import search
search.soundcloud_url_call('valen potloff demo', limit=5)
# Out:
# {'collection': [{'artwork_url': 'https://i1.sndcdn.com/artworks-71k92N4x03VV7Nv0-LJOnog-large.jpg',
#    'caption': None,
#    'commentable': True,
#    'comment_count': 1,
#    'created_at': '2024-01-11T21:03:16Z',
#    'description': 'learning to dj',
#    'downloadable': False,
#    'download_count': 0,
#    'duration': 4321176,
#    'full_duration': 4321176,
#    'embeddable_by': 'all',
#    'genre': 'Classical',
#    'has_downloads_left': False,
#    'id': 1714951461,
#    'kind': 'track',
#    'label_name': None,
#    'last_modified': '2024-01-11T21:03:18Z',
#    'license': 'all-rights-reserved',
#    'likes_count': 2,
#    'permalink': 'demo',
#    'permalink_url': 'https://soundcloud.com/valen-potloff/demo',
#    'playback_count': 10,
#    'public': True,
#    'publisher_metadata': {'id': 1714951461,
#     'urn': 'soundcloud:tracks:1714951461',
#     'contains_music': True},
#    'purchase_title': None,
#    'purchase_url': None,
#    'release_date': None,
# ...

# %%
import search
search.search_soundcloud('come aliv3')
# Out:
# [{'cover': 'https://i1.sndcdn.com/artworks-zWlsHiagmCdrOApn-wTgrzQ-large.png',
#   'comments': 183,
#   'date': '2024-11-26',
#   'duration_ms': 207464,
#   'duration_formatted': '3:27',
#   'likes': 6664,
#   'plays': 153652,
#   'artist': 'Knock2',
#   'title': 'RL Grime & Knock2 - come aliv3 ft. Abi Flynn',
#   'username': 'Knock2',
#   'link': 'https://soundcloud.com/knock2music/come-aliv3'},
#  {'cover': 'https://i1.sndcdn.com/artworks-0cYGtoz7nG3CZnAi-F9rgzQ-large.jpg',
#   'comments': 16,
#   'date': '2024-10-29',
#   'duration_ms': 216242,
#   'duration_formatted': '3:36',
#   'likes': 889,
#   'plays': 28288,
#   'artist': '',
#   'title': 'Knock2 x RL Grime - come aliv3 (Audio) [NOLIMIT] [Unreleased ID]',
#   'username': 'ISOKNOCK VAULT',
#   'link': 'https://soundcloud.com/zippyzeph/knock2-x-rl-grime-come-aliv3'},
#  {'cover': 'https://i1.sndcdn.com/artworks-ezFyA2Nutpsp2EeV-nEOFIQ-large.jpg',
#   'comments': 24,
#   'date': '2024-12-14',
#   'duration_ms': 210287,
# ...

# %%
import search
search.search_youtube('come aliv3')
# Out:
# [{'thumbnail': 'https://i.ytimg.com/vi/zQEbq2Lxm14/hqdefault.jpg?sqp=-oaymwEjCOADEI4CSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLBt0lIqyr_dw0bgCEbbGuYbfFkmmg',
#   'url': 'https://www.youtube.com/watch?v=zQEbq2Lxm14',
#   'channel': 'Knock2',
#   'duration': '3:28',
#   'title': 'RL Grime & Knock2 - come aliv3 (ft. Abi Flynn) [Official Visualizer]',
#   'views': '216,105 views'},
#  {'thumbnail': 'https://i.ytimg.com/vi/BURBlSYPmBU/hq720.jpg?sqp=-oaymwE9COgCEMoBSFryq4qpAy8IARUAAAAAGAElAADIQj0AgKJDeAHwAQH4Af4JgALQBYoCDAgAEAEYOSBDKH8wDw==&rs=AOn4CLBRSqhFPovgQdyk5r6_pfGEg-QS8w',
#   'url': 'https://www.youtube.com/watch?v=BURBlSYPmBU',
#   'channel': 'Atlantic Records',
#   'duration': '3:47',
#   'title': 'The Greatest Showman Cast - Come Alive (Official Audio)',
#   'views': '82,064,907 views'},
# ...

# %%
import download
download.download_yt('https://www.youtube.com/watch?v=zQEbq2Lxm14', filepath='test_downloads')
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=zQEbq2Lxm14
# [youtube] zQEbq2Lxm14: Downloading webpage
# [youtube] zQEbq2Lxm14: Downloading tv client config
# [youtube] zQEbq2Lxm14: Downloading player f3d47b5a
# [youtube] zQEbq2Lxm14: Downloading tv player API JSON
# [youtube] zQEbq2Lxm14: Downloading ios player API JSON
# [youtube] zQEbq2Lxm14: Downloading m3u8 information
# [info] zQEbq2Lxm14: Downloading 1 format(s): 251
# [download] Destination: test_downloads/RL Grime & Knock2 - come aliv3 (ft. Abi Flynn) [Official Visualizer] [zQEbq2Lxm14].webm
# [download] 100% of    3.12MiB in 00:00:00 at 7.59MiB/s
# [ExtractAudio] Destination: test_downloads/RL Grime & Knock2 - come aliv3 (ft. Abi Flynn) [Official Visualizer] [zQEbq2Lxm14].mp3
# Deleting original file test_downloads/RL Grime & Knock2 - come aliv3 (ft. Abi Flynn) [Official Visualizer] [zQEbq2Lxm14].webm (pass -k to keep)

# %%
import download 
download.download_sc('https://soundcloud.com/knock2music/come-aliv3', filepath='test_downloads')
